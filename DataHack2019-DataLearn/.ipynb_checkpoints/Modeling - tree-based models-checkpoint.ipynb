# %%
from datalearn19intro import (get_accounts, get_events, get_subscriptions, get_users)

## Data manipulation
import pandas as pd
import numpy as np

## Modeling
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Upload Data

# %%
# acc = pd.read_csv("Data/accounts.csv")
acc = get_accounts()
events = get_events()
subs = get_subscriptions()
users = get_users()

# %%
# change column names
acc.columns = 'acc_' + acc.columns 
events.columns = 'events_' + events.columns
subs.columns = 'subs_' + subs.columns
users.columns = 'users_' + users.columns

# %%
data = acc.copy()

acc_users = pd.merge(acc, users, left_on = 'acc_account_id', right_on = 'users_account_id', how = 'left')
acc_users = acc_users.loc[:, acc_users.columns != 'users_account_id']

acc_users_grouped = acc_users.groupby(['acc_account_id']).users_user_id.nunique().to_frame('unique_users')
acc_users_grouped['unique_cities_of_users'] = acc_users.groupby(['acc_account_id']).users_city.nunique().to_frame('unique_cities_of_users')
## add more aggregations
acc_users_grouped = acc_users_grouped.reset_index()

data = pd.merge(data, acc_users_grouped, 
               on = 'acc_account_id', how = 'left')

# %%
data
# Out:
#       acc_account_id acc_marketing_source  \
# 0            2793496                 bing
# 1            2793497                  NaN
# 2            2793498     adwordsverticals
# 3            2793499                  NaN
# 4            2793500       adwordsyoutube
# ...              ...                  ...
# 996          2794492             facebook
# 997          2794493            instagram
# 998          2794494                  NaN
# 999          2794495            instagram
# 1000         2794496                  NaN
#
#                             acc_marketing_referrer acc_created_at  \
# 0     https://www.bing.com/search?q=basecamp login     2019-01-01
# 1                                              NaN     2019-01-01
# 2                          https://www.google.com/     2019-01-01
# 3                                              NaN     2019-01-01
# 4                         https://www.youtube.com/     2019-01-01
# ...                                            ...            ...
# 996                          http://m.facebook.com     2019-01-01
# 997                          http://instagram.com/     2019-01-01
# 998                            https://monday.com/     2019-01-01
# 999                                            NaN     2019-01-01
# 1000                                           NaN     2019-01-01
#
#       acc_plan_id acc_trial_start acc_started_plan_at acc_signup_box_origin  \
# 0             NaN      2019-01-01                 NaN                   NaN
# 1             NaN      2019-01-01                 NaN            mobile_app
# 2             NaN      2019-01-01                 NaN                   NaN
# 3             NaN      2019-01-01                 NaN            mobile_app
# 4             NaN      2019-04-04                 NaN                   NaN
# ...           ...             ...                 ...                   ...
# 996           NaN      2019-01-01                 NaN                   NaN
# 997           NaN      2019-01-01                 NaN                   NaN
# 998           NaN      2019-01-01                 NaN                   NaN
# 999           NaN      2019-01-01                 NaN                   NaN
# 1000          NaN      2019-01-01                 NaN            mobile_app
#
#      acc_churn_state acc_churn_date  ...  acc_has_domain  acc_mrr  \
# 0               none            NaN  ...               0      NaN
# 1               none            NaN  ...               0      NaN
# 2               none            NaN  ...               0      NaN
# 3               none            NaN  ...               0      NaN
# 4               none            NaN  ...               0      NaN
# ...              ...            ...  ...             ...      ...
# 996             none            NaN  ...               1      NaN
# 997             none            NaN  ...               0      NaN
# 998             none            NaN  ...               1      NaN
# 999             none            NaN  ...               1      NaN
# 1000            none            NaN  ...               0      NaN
#
#      acc_lead_score acc_industry.1 acc_team_size  acc_user_goal  \
# 0                 0            NaN           NaN            NaN
# 1                 0            NaN           NaN            NaN
# 2                 0          Other             1            NaN
# 3                 0            NaN           NaN            NaN
# 4                 0         Design             1            NaN
# ...             ...            ...           ...            ...
# 996               0            NaN           NaN            NaN
# 997               0            NaN           NaN            NaN
# 998               0      Education             1            NaN
# 999               0            NaN           NaN            NaN
# 1000              0            NaN           NaN            NaN
#
#       acc_user_description  acc_sub_industry  unique_users  \
# 0                      NaN               NaN             1
# 1                      NaN               NaN             2
# 2                      NaN               NaN             1
# 3                      NaN               NaN             1
# 4                      NaN               NaN             1
# ...                    ...               ...           ...
# 996                    NaN               NaN             1
# 997                    NaN               NaN             1
# 998                    NaN               NaN             1
# 999                    NaN               NaN             4
# 1000                   NaN               NaN             1
#
#      unique_cities_of_users
# 0                         1
# 1                         2
# 2                         1
# 3                         1
# 4                         1
# ...                     ...
# 996                       0
# 997                       1
# 998                       1
# 999                       1
# 1000                      0
#
# [1001 rows x 51 columns]

# %% [markdown]
# # Train-test split

# %%
data.select_dtypes(include='float')
# Out:
#       acc_plan_id  acc_churn_reason  acc_time_diff  acc_free_users  \
# 0             NaN               NaN           11.0             NaN
# 1             NaN               NaN            NaN             NaN
# 2             NaN               NaN           -6.0             NaN
# 3             NaN               NaN            NaN             NaN
# 4             NaN               NaN           -5.0             NaN
# ...           ...               ...            ...             ...
# 996           NaN               NaN            1.0             NaN
# 997           NaN               NaN           -3.0             NaN
# 998           NaN               NaN            1.0             NaN
# 999           NaN               NaN            NaN             NaN
# 1000          NaN               NaN            5.5             NaN
#
#       acc_company_size  acc_last_upgrade_promotion_start  acc_cs_agent  \
# 0                  NaN                               NaN           NaN
# 1                  NaN                               NaN           NaN
# 2                  NaN                               NaN           NaN
# 3                  NaN                               NaN           NaN
# 4                  NaN                               NaN           NaN
# ...                ...                               ...           ...
# 996             5000.0                               NaN           NaN
# 997                NaN                               NaN           NaN
# 998              670.0                               NaN           NaN
# 999               15.0                               NaN           NaN
# 1000               NaN                               NaN           NaN
#
#       acc_sales_agent  acc_disabled  acc_max_team_size  acc_min_team_size  \
# 0                 NaN           NaN                5.0                2.0
# 1                 NaN           NaN                5.0                2.0
# 2                 NaN           NaN                1.0                1.0
# 3                 NaN           NaN                NaN                NaN
# 4                 NaN           NaN                1.0                1.0
# ...               ...           ...                ...                ...
# 996               NaN           NaN                0.0                0.0
# 997               NaN           NaN                NaN                NaN
# 998               NaN           NaN                1.0                1.0
# 999               NaN           NaN               10.0                6.0
# 1000              NaN           NaN                NaN                NaN
#
#       acc_cancellation_on_renewal_date  acc_partner_id  acc_mrr  \
# 0                                  NaN             NaN      NaN
# 1                                  NaN             NaN      NaN
# 2                                  NaN             NaN      NaN
# 3                                  NaN             NaN      NaN
# 4                                  NaN             NaN      NaN
# ...                                ...             ...      ...
# 996                                NaN           200.0      NaN
# 997                                NaN             NaN      NaN
# 998                                NaN             NaN      NaN
# 999                                NaN             NaN      NaN
# 1000                               NaN             NaN      NaN
#
#       acc_user_goal  acc_user_description  acc_sub_industry
# 0               NaN                   NaN               NaN
# 1               NaN                   NaN               NaN
# 2               NaN                   NaN               NaN
# 3               NaN                   NaN               NaN
# 4               NaN                   NaN               NaN
# ...             ...                   ...               ...
# 996             NaN                   NaN               NaN
# 997             NaN                   NaN               NaN
# 998             NaN                   NaN               NaN
# 999             NaN                   NaN               NaN
# 1000            NaN                   NaN               NaN
#
# [1001 rows x 17 columns]

# %%
y = data[['acc_lead_score']]
X = data.loc[:,(data.columns != 'acc_lead_score') & (data.columns != 'acc_account_id')]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
X_train.head()
# Out:
#     acc_marketing_source                   acc_marketing_referrer  \
# 250             capterra        https%3a%2f%2fwww.capterra.com%2f
# 940             facebook                    http://m.facebook.com
# 47                   NaN  https%3a%2f%2fmonday.com%2flang%2fes%2f
# 969                  NaN                      https://monday.com/
# 801        adwordssearch                  https://www.google.com/
#
#     acc_created_at  acc_plan_id acc_trial_start acc_started_plan_at  \
# 250     2019-01-01          NaN      2019-01-01                 NaN
# 940     2019-01-01          NaN      2019-01-01                 NaN
# 47      2019-01-01          NaN      2019-01-01                 NaN
# 969     2019-01-01          NaN      2019-01-14                 NaN
# 801     2019-01-01          NaN      2019-01-01                 NaN
#
#     acc_signup_box_origin acc_churn_state acc_churn_date  acc_churn_reason  \
# 250                   NaN            none            NaN               NaN
# 940                   NaN            none            NaN               NaN
# 47                    NaN            none            NaN               NaN
# 969                   NaN            none            NaN               NaN
# 801                   NaN            none            NaN               NaN
#
#      ...  acc_pricing_version acc_has_domain acc_mrr      acc_industry.1  \
# 250  ...                    3              0     NaN  Project Management
# 940  ...                    3              0     NaN                 NaN
# 47   ...                    3              1     NaN                 NaN
# 969  ...                    3              1     NaN           Marketing
# 801  ...                    3              1     NaN          Consulting
#
#      acc_team_size  acc_user_goal  acc_user_description  acc_sub_industry  \
# 250            2-5            NaN                   NaN               NaN
# 940            NaN            NaN                   NaN               NaN
# 47             NaN            NaN                   NaN               NaN
# 969           6-10            NaN                   NaN               NaN
# 801           6-10            NaN                   NaN               NaN
#
#     unique_users unique_cities_of_users
# 250            1                      1
# 940            1                      1
# 47             1                      1
# 969           15                      2
# 801            1                      1
#
# [5 rows x 49 columns]
